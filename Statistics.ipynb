# %%
from data_processing import CatDataProcessor
import pandas as pd

csv = pd.read_csv("dataset/cat_breed.csv")

proc = CatDataProcessor("dataset")
imgDf = proc.create_image_dataframe()

# %%
merged_df = proc.merge_dataframe(imgDf)

print(f"Length of Dataframe_folder {len(imgDf)}")
print(f"Length of CSV {len(csv)}")
print(f"Length of Dataframe {len(merged_df)}")

merged_df
# Out:
# Warning:: 43 breed mismatches are found between csv and folder
# Length of Dataframe_folder 119294
# Length of CSV 67706
# Length of Dataframe 63070
#                id                                          img_path  \
# 0        12136161        dataset\images\Abyssinian\12136161_252.jpg
# 1        13743713        dataset\images\Abyssinian\13743713_251.jpg
# 2        14092337        dataset\images\Abyssinian\14092337_250.jpg
# 3        14475392        dataset\images\Abyssinian\14475392_248.jpg
# 4        16485182        dataset\images\Abyssinian\16485182_247.jpg
# ...           ...                                               ...
# 63065  4633685859    dataset\images\York Chocolate\4633685859_4.jpg
# 63066  4633685860    dataset\images\York Chocolate\4633685860_4.jpg
# 63067  4633685861    dataset\images\York Chocolate\4633685861_4.jpg
# 63068  4633685862    dataset\images\York Chocolate\4633685862_4.jpg
# 63069    46336858  dataset\images\York Chocolate\46336858_40884.jpg
#
#                 breed
# 0          Abyssinian
# 1          Abyssinian
# 2          Abyssinian
# 3          Abyssinian
# 4          Abyssinian
# ...               ...
# 63065  York Chocolate
# 63066  York Chocolate
# 63067  York Chocolate
# 63068  York Chocolate
# 63069  York Chocolate
#
# [63070 rows x 3 columns]

# %%
df = proc.load_and_validate_data()
# Out:
# Warning:: 43 breed mismatches are found between csv and folder
# 63070 files are valid
# Final dataset : 63070 samples and 67 breeds
# Breeds : ['Abyssinian', 'American Bobtail', 'American Curl', 'American Shorthair', 'American Wirehair', 'Applehead Siamese', 'Balinese', 'Bengal', 'Birman', 'Bombay', 'British Shorthair', 'Burmese', 'Burmilla', 'Calico', 'Canadian Hairless', 'Chartreux', 'Chausie', 'Chinchilla', 'Cornish Rex', 'Cymric', 'Devon Rex', 'Dilute Calico', 'Dilute Tortoiseshell', 'Domestic Long Hair', 'Domestic Medium Hair', 'Domestic Short Hair', 'Egyptian Mau', 'Exotic Shorthair', 'Extra-Toes Cat - Hemingway Polydactyl', 'Havana', 'Himalayan', 'Japanese Bobtail', 'Javanese', 'Korat', 'LaPerm', 'Maine Coon', 'Manx', 'Munchkin', 'Nebelung', 'Norwegian Forest Cat', 'Ocicat', 'Oriental Long Hair', 'Oriental Short Hair', 'Oriental Tabby', 'Persian', 'Pixiebob', 'Ragamuffin', 'Ragdoll', 'Russian Blue', 'Scottish Fold', 'Selkirk Rex', 'Siamese', 'Siberian', 'Silver', 'Singapura', 'Snowshoe', 'Somali', 'Sphynx - Hairless Cat', 'Tabby', 'Tiger', 'Tonkinese', 'Torbie', 'Tortoiseshell', 'Turkish Angora', 'Turkish Van', 'Tuxedo', 'York Chocolate']

# %%
df
# Out:
#                id                                          img_path  \
# 0        12136161        dataset\images\Abyssinian\12136161_252.jpg
# 1        13743713        dataset\images\Abyssinian\13743713_251.jpg
# 2        14092337        dataset\images\Abyssinian\14092337_250.jpg
# 3        14475392        dataset\images\Abyssinian\14475392_248.jpg
# 4        16485182        dataset\images\Abyssinian\16485182_247.jpg
# ...           ...                                               ...
# 63065  4633685859    dataset\images\York Chocolate\4633685859_4.jpg
# 63066  4633685860    dataset\images\York Chocolate\4633685860_4.jpg
# 63067  4633685861    dataset\images\York Chocolate\4633685861_4.jpg
# 63068  4633685862    dataset\images\York Chocolate\4633685862_4.jpg
# 63069    46336858  dataset\images\York Chocolate\46336858_40884.jpg
#
#                 breed
# 0          Abyssinian
# 1          Abyssinian
# 2          Abyssinian
# 3          Abyssinian
# 4          Abyssinian
# ...               ...
# 63065  York Chocolate
# 63066  York Chocolate
# 63067  York Chocolate
# 63068  York Chocolate
# 63069  York Chocolate
#
# [63070 rows x 3 columns]

# %%
breed_counts = df['breed'].value_counts()
print("--- 🐱 breed and their number of data ---")
print(breed_counts)
# Out:
# --- 🐱 breed and their number of data ---
# breed
# Persian                 3741
# Domestic Short Hair     3693
# Domestic Long Hair      3667
# Domestic Medium Hair    3601
# American Shorthair      3501
#                         ...
# Chinchilla                61
# Somali                    61
# Burmilla                  60
# Chausie                   60
# Canadian Hairless         46
# Name: count, Length: 67, dtype: int64

# %%
sample_below = breed_counts[breed_counts <= 70]
print(sample_below)
# Out:
# breed
# American Wirehair     70
# Selkirk Rex           69
# Cymric                67
# Korat                 67
# LaPerm                64
# York Chocolate        64
# Oriental Long Hair    62
# Javanese              61
# Chinchilla            61
# Somali                61
# Burmilla              60
# Chausie               60
# Canadian Hairless     46
# Name: count, dtype: int64

# %%
train, val, test = proc.create_train_validation_test_split()

# %%
train
# Out:
#              id                                           img_path  \
# 6790   42976014            dataset\images\Bengal\42976014_1587.jpg
# 25259  46584579  dataset\images\Domestic Medium Hair\46584579_1...
# 45934  43698711      dataset\images\Russian Blue\43698711_4443.jpg
# 19827  45955136  dataset\images\Domestic Long Hair\45955136_669...
# 40982  37858173           dataset\images\Persian\37858173_3002.jpg
# ...         ...                                                ...
# 1917   43883352  dataset\images\American Shorthair\43883352_594...
# 29539  46744198  dataset\images\Domestic Short Hair\46744198_20...
# 20292  46054824  dataset\images\Domestic Long Hair\46054824_578...
# 5842   31855706            dataset\images\Bengal\31855706_5161.jpg
# 46460  45610638      dataset\images\Russian Blue\45610638_1936.jpg
#
#                       breed
# 6790                 Bengal
# 25259  Domestic Medium Hair
# 45934          Russian Blue
# 19827    Domestic Long Hair
# 40982               Persian
# ...                     ...
# 1917     American Shorthair
# 29539   Domestic Short Hair
# 20292    Domestic Long Hair
# 5842                 Bengal
# 46460          Russian Blue
#
# [45410 rows x 3 columns]

# %%
val
# Out:
#              id                                           img_path  \
# 10828  45350267            dataset\images\Calico\45350267_4791.jpg
# 1552   43326261  dataset\images\American Shorthair\43326261_685...
# 42031  44134058            dataset\images\Persian\44134058_948.jpg
# 20322  46062763  dataset\images\Domestic Long Hair\46062763_573...
# 124    44186717         dataset\images\Abyssinian\44186717_117.jpg
# ...         ...                                                ...
# 21890  46513988  dataset\images\Domestic Long Hair\46513988_229...
# 300    20357543  dataset\images\American Bobtail\20357543_4254.jpg
# 32314  23606529             dataset\images\Havana\23606529_479.jpg
# 32610  33727151         dataset\images\Himalayan\33727151_2656.jpg
# 34888  45946253        dataset\images\Maine Coon\45946253_1847.jpg
#
#                     breed
# 10828              Calico
# 1552   American Shorthair
# 42031             Persian
# 20322  Domestic Long Hair
# 124            Abyssinian
# ...                   ...
# 21890  Domestic Long Hair
# 300      American Bobtail
# 32314              Havana
# 32610           Himalayan
# 34888          Maine Coon
#
# [11353 rows x 3 columns]

# %%
test
# Out:
#              id                                           img_path  \
# 29792  46746152  dataset\images\Domestic Short Hair\46746152_14...
# 43891  31902124           dataset\images\Ragdoll\31902124_4136.jpg
# 19021  43449121  dataset\images\Dilute Tortoiseshell\43449121_1...
# 42659  25515402         dataset\images\Ragamuffin\25515402_318.jpg
# 10431  45019398            dataset\images\Calico\45019398_5958.jpg
# ...         ...                                                ...
# 58606  45675744     dataset\images\Tortoiseshell\45675744_2343.jpg
# 37789  31291066  dataset\images\Norwegian Forest Cat\31291066_1...
# 25277  46588678  dataset\images\Domestic Medium Hair\46588678_1...
# 15584  41728837     dataset\images\Dilute Calico\41728837_2404.jpg
# 11948  46045587            dataset\images\Calico\46045587_2196.jpg
#
#                       breed
# 29792   Domestic Short Hair
# 43891               Ragdoll
# 19021  Dilute Tortoiseshell
# 42659            Ragamuffin
# 10431                Calico
# ...                     ...
# 58606         Tortoiseshell
# 37789  Norwegian Forest Cat
# 25277  Domestic Medium Hair
# 15584         Dilute Calico
# 11948                Calico
#
# [6307 rows x 3 columns]

# %%
train_gen, val_gen, test_gen = proc.create_data_generator(train, val, test)
# Out:
# Found 45410 validated image filenames belonging to 67 classes.
# Found 11353 validated image filenames belonging to 67 classes.
# Found 6307 validated image filenames belonging to 67 classes.

# %%
print(train_gen.samples)
print(val_gen.samples)
print(test_gen.samples)
# Out:
# 45410
# 11353
# 6307

# %%
proc.analyze_class_distribution(train, val, test)
